# %% [markdown]
# # MedGemma Inference Demo
#
# Single-shot medical image analysis powered by MedGemma on SageMaker.
#
# | Feature | Status |
# |---|---|
# | Single-image inference | **Available** |
# | Endpoint configuration UI | *Coming soon* |
# | Multi-turn conversation | *Coming soon* |
# | Batch inference | *Coming soon* |
#
# > Running inside XNAT Jupyter. DICOM files are expected on the mounted filesystem.
#
# ---
# ### Usage Notes
# - **DICOM Windowing**: The viewer applies DICOM windowing metadata when available. Fallback defaults — CT: soft-tissue (C:40/W:400), X-ray: full 12-bit range, MR: auto from pixel stats.
# - **Supported modalities**: X-ray (CR/DX), CT, MRI — one slice at a time.
# - **Endpoint cold start**: First request after deploy may take 5-10 minutes. Subsequent requests respond in seconds.
# - **AWS credentials**: Set `AWS_ACCESS_KEY_ID` and `AWS_SECRET_ACCESS_KEY` as environment variables before launching.

# %%
from utils import build_and_display_app

build_and_display_app()
