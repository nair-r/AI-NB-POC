# %%
from IPython.display import display, HTML

display(HTML("""
<div style="background:#1e88e5;color:#fff;padding:20px 28px;
            border-radius:8px;font-family:sans-serif;font-size:18px;">
    Hello from Voila &#x2714;
</div>
"""))
